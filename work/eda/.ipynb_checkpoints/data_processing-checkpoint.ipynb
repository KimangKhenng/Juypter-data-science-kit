# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
school = pd.read_csv("School_Attendance_by_Student_Group.csv")

# %%
school = school.drop(['2020-2021 student count','2020-2021 attendance rate','2019-2020 student count','2019-2020 attendance rate'], axis=1)

# %%
school.head()
# Out:
#   StoreId                                  uuid             createdAt  \
# 0    aj85  001acc32-816b-41f3-9c25-7e23af4e414f  2023-09-24T13:58:30Z
# 1    n964  00213503-ca54-448a-98d8-0a9cea483b9a  2024-01-21T13:30:20Z
# 2    neo8  002b14a4-410d-48aa-91c4-e2b8a06166aa  2023-09-18T11:02:54Z
# 3    mf6i  002f56fa-8a63-4abf-8035-7d7fb307f540  2024-01-22T08:20:45Z
# 4    t86n  0038f7b7-f76e-4cc6-af8c-ce43b57abb75  2023-08-16T03:45:44Z
#
#               updatedAt                                               text  \
# 0  2023-09-24T13:58:30Z  Chicken was pink. Did not eat and woukd not or...
# 1  2024-01-21T13:30:20Z                                               Nice
# 2  2023-09-18T11:02:54Z                                      ដាក់ត្រីខុស​
# 3  2024-01-22T08:20:45Z               Love love love love it was so great
# 4  2023-08-16T03:45:44Z  Didn't follow cooking instructions.\nIgnored r...
#
#    isAnonymous reviewerId replies  likeCount  isLiked  overall  \
# ...

# %%
categories_count = school['Category'].value_counts()
plt.figure(figsize=(14,6))
plt.bar(categories_count.index, categories_count)
plt.title('Count plot of Category')
plt.xlabel('Category')
plt.ylabel('Count')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Category'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 categories_count = school['Category'].value_counts()
# ...

# %%
school.sample(50)
# Out:
#      District code                                      District name  \
# 132        0150011                         Bridgeport School District
# 1786       2640013             Integrated Day Charter School District
# 1650       2150012                        Regional School District 15
# 1740       2440014              Area Cooperative Educational Services
# 1727       2430014                   Cooperative Educational Services
# 1164       1310011                        Southington School District
# 602        0680011                               Kent School District
# 978        1090011                         Plainfield School District
# 1931       2940013                 Great Oaks Charter School District
# 647        0740011                         Litchfield School District
# 1666       2170012                        Regional School District 17
# 1405       1560011                         West Haven School District
# ...

# %%
missing = school.isnull().sum()

# %%
totalCells = np.product(school.shape)

# %%
totalMissing = missing.sum()

# %%
missingPercent = (totalMissing/totalCells)*100

# %%
print("The dataset School_Attendance_by_Student_Group contains", round(missingPercent,2),"% missing values.")
# Out:
# The dataset School_Attendance_by_Student_Group contains 3.23 % missing values.
