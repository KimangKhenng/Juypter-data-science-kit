# %%
import pandas as pd
import edvart

# %%
school = pd.read_csv("School_Attendance_by_Student_Group.csv")
school.drop(['Reporting period','Date update'], inplace=True, axis=1)

# %%
report = edvart.DefaultReport(school)
# Show the report in the current Jupyter notebook
report.export_notebook("report.ipynb")
report.show()
# Out:
# # Table of Contents
# ---
#  * [Overview](#4e7b41e5-ffe0-4949-b90b-ec07c5753555)
#
# 	 * [Quick Info](#bd051940-0d38-4f3e-978e-073ab810b450)
#
# 	 * [Data Types](#46016d51-be8b-465a-99df-839a2f26daf3)
#
# 	 * [Data Preview](#be5dcc7e-4b58-4c89-84a8-dc5ad1a38338)
#
# 	 * [Missing Values](#d39e5099-6f4f-4f42-a715-74203d688c3e)
#
# 	 * [Rows With Missing Value](#461568c9-3dfd-4dd6-87ed-6b4c89e614ad)
#
# 	 * [Constant Occurrence](#25a637c8-92a4-41b4-acb9-cd93c7f20917)
#
# 	 * [Duplicate Rows](#001542af-21e0-481c-9fd5-b7b53757f2ea)
#
#  * [Univariate Analysis](#6ffca2dc-45fd-4600-8285-709cf5a13f88)
#
#  * [Bivariate analysis](#d58c6e10-3eca-4252-97a0-6333421c584f)
#
# 	 * [Correlation Plot](#afa2959b-1773-48be-bf87-b404344939f8)
#
# 	 * [Pairplot](#12ae8698-009c-472a-a773-ec76f15a9df5)
#
# 	 * [Contingency table](#f437b93d-561b-4ae5-83bc-8b3be6a61e98)
#
#  * [Multivariate analysis](#b49e8964-ccce-46f5-b5b9-ac47366db480)
#
# ...
