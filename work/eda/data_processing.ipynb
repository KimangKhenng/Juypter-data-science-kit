# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
school = pd.read_csv("School_Attendance_by_Student_Group.csv")

# %%
school.head()
# Out:
#   District code District name                    Category  \
# 0       00000CT   Connecticut                         NaN
# 1       00000CT   Connecticut                Homelessness
# 2       00000CT   Connecticut  Students With Disabilities
# 3       00000CT   Connecticut          Free/Reduced Lunch
# 4       00000CT   Connecticut          Free/Reduced Lunch
#
#                         Student group  2021-2022 student count - year to date  \
# 0                        All Students                                  500285
# 1  Students Experiencing Homelessness                                    1814
# 2          Students With Disabilities                                   78417
# 3                  Free Meal Eligible                                  168984
# 4         Reduced Price Meal Eligible                                   29905
#
#    2021-2022 attendance rate - year to date  2020-2021 student count  \
# 0                                    0.9169                 496092.0
# ...

# %%
categories_count = school['Category'].value_counts()
plt.figure(figsize=(14,6))
plt.bar(categories_count.index, categories_count)
plt.title('Count plot of Category')
plt.xlabel('Category')
plt.ylabel('Count')
plt.show()

# %%
school.sample(50)
# Out:
#      District code                                      District name  \
# 578        0640011                           Hartford School District
# 388        0450011                          East Lyme School District
# 1778       2630013                  Odyssey Community School District
# 1956       2970013         Capital Preparatory Harbor School District
# 534        0590011                             Groton School District
# 1200       1350011                           Stamford School District
# 457        0510011                          Fairfield School District
# 1981       9000016  Connecticut Technical Education and Career System
# 608        0690011                          Killingly School District
# 1735       2430014                   Cooperative Educational Services
# 653        0760011                            Madison School District
# 1382       1550011                      West Hartford School District
# ...

# %%
missing = school.isnull().sum()

# %%
totalCells = np.product(school.shape)

# %%
totalMissing = missing.sum()

# %%
missingPercent = (totalMissing/totalCells)*100

# %%
print("The dataset School_Attendance_by_Student_Group contains", round(missingPercent,2),"% missing values.")
# Out:
# The dataset School_Attendance_by_Student_Group contains 1.8 % missing values.

# %%
school.nunique() #nunique = number of unique,
# Out:
# District code                                201
# District name                                201
# Category                                       6
# Student group                                 13
# 2021-2022 student count - year to date      1096
# 2021-2022 attendance rate - year to date     845
# 2020-2021 student count                     1104
# 2020-2021 attendance rate                    980
# 2019-2020 student count                     1114
# 2019-2020 attendance rate                    557
# Reporting period                               1
# Date update                                    1
# dtype: int64

# %%
# Replace Null Value
school.replace(np.nan, '0', inplace=True)
school.isnull().sum()
# Out:
# District code                               0
# District name                               0
# Category                                    0
# Student group                               0
# 2021-2022 student count - year to date      0
# 2021-2022 attendance rate - year to date    0
# 2020-2021 student count                     0
# 2020-2021 attendance rate                   0
# 2019-2020 student count                     0
# 2019-2020 attendance rate                   0
# Reporting period                            0
# Date update                                 0
# dtype: int64

# %%
school[school['District code']=='0780011']
# Out:
#     District code              District name                    Category  \
# 674       0780011  Mansfield School District                           0
# 675       0780011  Mansfield School District  Students With Disabilities
# 676       0780011  Mansfield School District          Free/Reduced Lunch
# 677       0780011  Mansfield School District          Free/Reduced Lunch
# 678       0780011  Mansfield School District          Free/Reduced Lunch
# 679       0780011  Mansfield School District            English Learners
# 680       0780011  Mansfield School District              Race/Ethnicity
# 681       0780011  Mansfield School District              Race/Ethnicity
# 682       0780011  Mansfield School District              Race/Ethnicity
# 683       0780011  Mansfield School District              Race/Ethnicity
# 684       0780011  Mansfield School District                  High Needs
# 685       0780011  Mansfield School District                  High Needs
#
# ...

# %%
school.duplicated().sum()
# Out:
# 0
